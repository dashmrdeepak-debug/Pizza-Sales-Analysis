# %% [markdown]
# # pizza sales analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px

# %% [markdown]
# ## import raw data

# %%
df=pd.read_csv("C:/Users/dashm/OneDrive/Desktop/personalnote/pizza_sales.csv")

# %% [markdown]
# ## metadata of raw data

# %%
df.head(10)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0         1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1         2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2         3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3         4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4         5         2     mexicana_m         1  01-01-2015   11:57:40
# 5         6         2     thai_ckn_l         1  01-01-2015   11:57:40
# 6         7         3    ital_supr_m         1  01-01-2015   12:12:28
# 7         8         3   prsc_argla_l         1  01-01-2015   12:12:28
# 8         9         4    ital_supr_m         1  01-01-2015   12:16:31
# 9        10         5    ital_supr_m         1  01-01-2015   12:21:30
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# ...

# %%
df.tail()
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# 48615       16.75        16.75          M        Chicken
# 48616       17.95        17.95          L         Veggie
# 48617       12.00        12.00          S        Classic
# 48618       20.25        20.25          L         Veggie
# 48619       12.75        12.75          S        Chicken
#
#                                        pizza_ingredients  \
# 48615  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# ...

# %%
df.tail(2)
# Out:
#        pizza_id  order_id pizza_name_id  quantity  order_date order_time  \
# 48618     48619     21349    mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350     bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# 48618       20.25        20.25          L         Veggie
# 48619       12.75        12.75          S        Chicken
#
#                                        pizza_ingredients  \
# 48618  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 48619  Barbecued Chicken, Red Peppers, Green Peppers,...
#
#                        pizza_name
# 48618          The Mexicana Pizza
# 48619  The Barbecue Chicken Pizza

# %%
print(df.shape)
# Out:
# (48620, 12)

# %%
print("meatadata tot row",df.shape[0])
# Out:
# meatadata tot row 48620

# %%
df.columns
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df.info
# Out:
# <bound method DataFrame.info of        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
# ...

# %% [markdown]
# ## data type with rawdata

# %%
df.dtypes
# Out:
# pizza_id               int64
# order_id               int64
# pizza_name_id         object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %% [markdown]
# ## KPIS

# %%
total_revenue=df.total_price.sum()
total_pizza_sold=df.quantity.sum()
total_orders=df.order_id.nunique()
avg_order_values=total_revenue/total_orders
avg_pizzas_per_order=total_pizza_sold/total_orders
print(total_revenue)
print(f"total_revenue:${total_revenue:,.2f}")
print(f"total_pizza_sold:{total_pizza_sold:,}")
print(f"total_orders:{total_orders:,}")
print(f"avg_order_values:{avg_order_values:,.2f}")
print(f"avg_pizzas_per_order:{avg_pizzas_per_order:,.2f}")
# Out:
# 817860.05
# total_revenue:$817,860.05
# total_pizza_sold:49,574
# total_orders:21,350
# avg_order_values:38.31
# avg_pizzas_per_order:2.32

# %% [markdown]
# ## chart's

# %%
ingrediant=(df['pizza_ingredients'].str.split(',').explode().str.strip().value_counts()
            .reset_index()).rename(columns={'count':'count143','pizza_ingredients':'ingrediants'})
print(ingrediant.head(10))
# Out:
#          ingrediants  count143
# 0             Garlic     27422
# 1           Tomatoes     26601
# 2         Red Onions     19547
# 3        Red Peppers     16284
# 4  Mozzarella Cheese     10333
# 5          Pepperoni     10300
# 6            Spinach     10012
# 7          Mushrooms      9624
# 8            Chicken      8443
# 9          Capocollo      6572

# %% [markdown]
# ## Daily Trend-Total Orders

# %%
df['order_date']=pd.to_datetime(df['order_date'],dayfirst=True)
df['day_name']=df['order_date'].dt.day_name()
weekday_order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
df['day_name']=pd.Categorical(df['day_name'],categories=weekday_order,ordered=True)
orders_by_day=df.groupby('day_name',observed=False)['order_id'].nunique()
ax=orders_by_day.plot(kind='bar',figsize=(8,5),color='green',edgecolor='black')
plt.title("Total Orders by Day of Week")
plt.xlabel("Day Of Week")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

for i,val in enumerate(orders_by_day):
    plt.text(i,val+20,str(val),ha="center",va="bottom",fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Daily Trend-Total Revenue

# %% [markdown]
# ## Daily Trend-Total Revenue

# %% [markdown]
# ## Daily Trend-Total Revenue

# %%
df['order_date']=pd.to_datetime(df['order_date'],dayfirst=True)
df['day_name']=df['order_date'].dt.day_name()
weekday_order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
df['day_name']=pd.Categorical(df['day_name'],categories=weekday_order,ordered=True)
orders_by_day=df.groupby('day_name',observed=False)['total_price'].sum()
ax=orders_by_day.plot(kind='bar',figsize=(8,5),color='purple',edgecolor='black')
plt.title("Total revenue by Day of Week")
plt.xlabel("Day Of Week")
plt.ylabel("Number of Revenue")
plt.xticks(rotation=45)

for i,val in enumerate(orders_by_day):
    plt.text(i,val+20,str(val),ha="center",va="bottom",fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hourly Trend-Total Order

# %%
df['order_time']=pd.to_datetime(df['order_time'],format="%H:%M:%S")
df['day_hour']=df['order_time'].dt.hour

orders_by_hour=df.groupby('day_hour',observed=False)['order_id'].nunique()
ax=orders_by_hour.plot(kind='bar',figsize=(8,5),color='purple',edgecolor='black')
plt.title("Total orders by hour of day")
plt.xlabel("hour of the day(24 format)")
plt.ylabel("Number of orders")
plt.xticks(rotation=45)

for i,val in enumerate(orders_by_hour):
    plt.text(i,val+20,str(val),ha="center",va="bottom",fontsize=9,fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Orders by Month

# %%
df['order_date']=pd.to_datetime(df['order_date'],dayfirst=True)
df['month_name']=df['order_date'].dt.month_name()
month_order=["January","February","March","April","May","June","July","August","September","October","November","December"]
df['day_name']=pd.Categorical(df['month_name'],categories=month_order,ordered=True)
orders_by_month=df.groupby('month_name',observed=False)['order_id'].nunique()
plt.figure(figsize=(10,5))
plt.fill_between(orders_by_month.index,orders_by_month.values,color="orange",alpha=0.3)

plt.plot(orders_by_month.index,orders_by_month.values,color='green',linewidth=1,marker='p')
plt.title("Total orders by month")
plt.xlabel("month")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

for i,val in enumerate(orders_by_month):
    plt.text(i,val+20,str(val),ha="center",va="bottom",fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## % of Sales Category

# %%
category_sales=df.groupby('pizza_category')['total_price'].sum()
category_pct=category_sales/category_sales.sum()*100
plt.figure(figsize=(7,7))
colors=plt.get_cmap('tab20').colors
plt.pie(category_pct,labels=category_pct.index,autopct='%1.1f%%',startangle=90,colors=colors,wedgeprops={'edgecolor':'black','width':0.4})
plt.title("percentage of sales by pizza category")
plt.show()

# %% [markdown]
# ## % sales by pizza size and category

# %%
sales_pivot=df.pivot_table(index='pizza_category',
                           columns='pizza_size',
                           values='total_price',
                           aggfunc='sum',fill_value=0)
sales_pct=sales_pivot/sales_pivot.sum().sum()*100
plt.figure(figsize=(10,6))
sns.heatmap(sales_pct,annot=True,fmt=".1f",cmap="YlOrRd",linewidth=0.5)
plt.title("% of sales by pizza category and size")
plt.ylabel("pizza category")
plt.xlabel("pizza size")
plt.show()

# %% [markdown]
# ## Total Pizza Sold By Pizza Category

# %%
pizzas_by_category=df.groupby('pizza_category')['quantity'].sum()
colors=list(plt.get_cmap('tab20').colors)
colors=colors[:len(pizzas_by_category)]
ax=pizzas_by_category.plot(kind='bar',figsize=(8,5),color=colors,edgecolor="black")
plt.title("total Pizzas sold by pizza category")
plt.xlabel("pizza category")
plt.ylabel("total pizzas sold")
plt.xticks(rotation=45)

for i,val in enumerate(pizzas_by_category):
    plt.text(i,val+5,str(val),ha='center',va='bottom',fontsize=9,fontweight='bold')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## top 5 best pizza selling-tot quantity

# %%
pizzas_by_name=df.groupby('pizza_name')['quantity'].sum()
top5=pizzas_by_name.sort_values(ascending=False).head(5)
ax=top5.plot(kind='bar',figsize=(8,5),color='grey',edgecolor='black')
plt.title('top5 pizzas sold')
plt.xlabel("pizza name")
plt.ylabel("total pizza sold")
plt.xticks(rotation=45)

for i,val in enumerate(top5):
    plt.text(i,val+11,str(val),ha="center",va="bottom",fontsize=9,fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## bottom 5 best pizza

# %%
pizzas_by_name=df.groupby('pizza_name')['quantity'].sum()
bottom5=pizzas_by_name.sort_values(ascending=True).head(5)
ax=bottom5.plot(kind='bar',figsize=(8,5),color='blue',edgecolor='black')
plt.title('top5 pizzas sold')
plt.xlabel("pizza name")
plt.ylabel("total pizza sold")
plt.xticks(rotation=45)

for i,val in enumerate(bottom5):
    plt.text(i,val+11,str(val),ha="center",va="bottom",fontsize=9,fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top5 best selling pizza-tot order

# %%
pizzas_by_name=df.groupby('pizza_name')['order_id'].nunique()
top5=pizzas_by_name.sort_values(ascending=False).head(5)
ax=top5.plot(kind='bar',figsize=(8,5),color='brown',edgecolor='black')
plt.title('top5 pizzas sold ordered')
plt.xlabel("pizza name")
plt.ylabel("total pizza sold")
plt.xticks(rotation=45)

for i,val in enumerate(top5):
    plt.text(i,val+11,str(val),ha="center",va="bottom",fontsize=9,fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## top 5 best selling -total sales

# %%
pizzas_by_name=df.groupby('pizza_name')['total_price'].sum()
top5=pizzas_by_name.sort_values(ascending=False).head(5)
ax=top5.plot(kind='bar',figsize=(8,5),color='orange',edgecolor='black')
plt.title('top5 pizzas sold ordered')
plt.xlabel("pizza name")
plt.ylabel("total pizza sold")
plt.xticks(rotation=45)

for i,val in enumerate(top5):
    plt.text(i,val+11,str(val),ha="center",va="bottom",fontsize=9,fontweight="bold")

plt.tight_layout()
plt.show()
